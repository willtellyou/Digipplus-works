# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
browser=webdriver.Chrome("chromedriver.exe")
browser.get("https://www.linkedin.com")
# Out:
# C:\Users\dell\AppData\Local\Temp/ipykernel_27168/2139254806.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser=webdriver.Chrome("chromedriver.exe")

# %%
username=browser.find_element_by_id("session_key")
username.send_keys("Your Email I'd")
password=browser.find_element_by_id("session_password")
password.send_keys("Your password")
# Out:
# C:\Users\dell\AppData\Local\Temp/ipykernel_27168/2703503692.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   username=browser.find_element_by_id("session_key")
# C:\Users\dell\AppData\Local\Temp/ipykernel_27168/2703503692.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   password=browser.find_element_by_id("session_password")

# %%
login_button=browser.find_element_by_class_name("sign-in-form__submit-button")
login_button.click()
# Out:
# C:\Users\dell\AppData\Local\Temp/ipykernel_27168/3225200103.py:1: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   login_button=browser.find_element_by_class_name("sign-in-form__submit-button")

# %%
browser.get("https://www.linkedin.com/search/results/people/?keywords=indian%20institute%20of%20technology%2C%20kharagpur%20%20alumni&origin=SWITCH_SEARCH_VERTICAL")

# %%
Alumni=browser.find_elements_by_class_name("app-aware-link")
c=[]
for i in Alumni:
    c.append(i.text)
    print(i.text)
# Out:
# C:\Users\dell\AppData\Local\Temp/ipykernel_27168/3859269128.py:1: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   Alumni=browser.find_elements_by_class_name("app-aware-link")
# Bhumi Tayal
# Bhumi Tayal
# View Bhumi Tayal’s profile
# Akshay Bhoite
# Shubham Ekapure
# 76 other shared connections
#
# Alakh Dixit
# View Alakh Dixit’s profile
# Meet Joshi
# Rushali Chakraborty
# 45 other shared connections
#
# Rohan Ishwarkar
# View Rohan Ishwarkar’s profile
# Meet Joshi
# Nikhil Yadav
# 43 other shared connections
#
# Ananya Singh
# View Ananya Singh’s profile
# Provides services - Graphic Design, Video Editing, Videography, WordPress Design, Wealth Management, Android Development, Content Strategy, Editing, Blogging, Translation
#
# Nitika Shroff
# View Nitika Shroff’s profile
# Abhinav Yadav
# Meet Joshi
# 54 other shared connections
#
# Divayum Gupta
# View Divayum Gupta’s profile
# Abhinav Yadav
# ...
